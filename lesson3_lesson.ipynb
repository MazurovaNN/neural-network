# %% [markdown]
# <a href="https://colab.research.google.com/github/MazurovaNN/neural-network/blob/main/lesson3_lesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.layers import *
import matplotlib.pyplot as plt
import numpy as np
import keras.utils
from tensorflow.keras.preprocessing import image

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train[:20]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5, 0, 9, 5, 5, 7, 9, 1, 0, 6, 4],
#       dtype=uint8)

# %%
for i in range(7):
    plt.subplot(4,7,i+1)
    plt.imshow(x_train[i])
plt.show()

# %%
input_shape = (28, 28, 1)

# %%
model_1 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      # Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      # MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(50,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_1.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
x_train = x_train / 255
x_test = x_test / 255
y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat = keras.utils.to_categorical(y_test, 10)

# %%
# %%time

history = model_1.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.3969 - accuracy: 0.8620 - val_loss: 0.3194 - val_accuracy: 0.8858
# Epoch 2/5
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2754 - accuracy: 0.9007 - val_loss: 0.3280 - val_accuracy: 0.8831
# Epoch 3/5
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.2338 - accuracy: 0.9144 - val_loss: 0.2730 - val_accuracy: 0.9028
# Epoch 4/5
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2078 - accuracy: 0.9235 - val_loss: 0.2797 - val_accuracy: 0.8968
# Epoch 5/5
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.1826 - accuracy: 0.9315 - val_loss: 0.2784 - val_accuracy: 0.9011
# CPU times: user 4min 24s, sys: 7.06 s, total: 4min 31s
# Wall time: 3min 23s

# %%
model_2 = keras.Sequential([
      keras.Input(shape=input_shape),
      Flatten(),
      Dense(50, activation = 'relu'),
      Dense(10, activation = 'softmax')
      ] )

# %%
model_2.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_2.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5284 - accuracy: 0.8165 - val_loss: 0.4606 - val_accuracy: 0.8410
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4036 - accuracy: 0.8569 - val_loss: 0.3998 - val_accuracy: 0.8573
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3682 - accuracy: 0.8694 - val_loss: 0.4129 - val_accuracy: 0.8520
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3448 - accuracy: 0.8770 - val_loss: 0.3775 - val_accuracy: 0.8642
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3270 - accuracy: 0.8827 - val_loss: 0.3887 - val_accuracy: 0.8597
# CPU times: user 28.2 s, sys: 1.47 s, total: 29.7 s
# Wall time: 43.1 s

# %%
model_3 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(50,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_3.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_3.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 76s 40ms/step - loss: 0.4311 - accuracy: 0.8450 - val_loss: 0.3375 - val_accuracy: 0.8794
# Epoch 2/5
# 1875/1875 [==============================] - 73s 39ms/step - loss: 0.2811 - accuracy: 0.8991 - val_loss: 0.2867 - val_accuracy: 0.8952
# Epoch 3/5
# 1875/1875 [==============================] - 73s 39ms/step - loss: 0.2372 - accuracy: 0.9138 - val_loss: 0.2591 - val_accuracy: 0.9065
# Epoch 4/5
# 1875/1875 [==============================] - 73s 39ms/step - loss: 0.2043 - accuracy: 0.9260 - val_loss: 0.2658 - val_accuracy: 0.9008
# Epoch 5/5
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.1813 - accuracy: 0.9323 - val_loss: 0.2442 - val_accuracy: 0.9141
# CPU times: user 9min 28s, sys: 10.1 s, total: 9min 38s
# Wall time: 6min 6s

# %%
model_4 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_4.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_4.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 113s 59ms/step - loss: 0.4361 - accuracy: 0.8414 - val_loss: 0.2955 - val_accuracy: 0.8941
# Epoch 2/10
# 1875/1875 [==============================] - 105s 56ms/step - loss: 0.2744 - accuracy: 0.8992 - val_loss: 0.2702 - val_accuracy: 0.9036
# Epoch 3/10
# 1875/1875 [==============================] - 104s 56ms/step - loss: 0.2291 - accuracy: 0.9164 - val_loss: 0.2568 - val_accuracy: 0.9081
# Epoch 4/10
# 1875/1875 [==============================] - 108s 58ms/step - loss: 0.1992 - accuracy: 0.9265 - val_loss: 0.2366 - val_accuracy: 0.9138
# Epoch 5/10
# 1875/1875 [==============================] - 103s 55ms/step - loss: 0.1752 - accuracy: 0.9345 - val_loss: 0.2536 - val_accuracy: 0.9142
# Epoch 6/10
# 1875/1875 [==============================] - 104s 55ms/step - loss: 0.1573 - accuracy: 0.9410 - val_loss: 0.2471 - val_accuracy: 0.9145
# Epoch 7/10
# 1875/1875 [==============================] - 103s 55ms/step - loss: 0.1371 - accuracy: 0.9490 - val_loss: 0.2342 - val_accuracy: 0.9205
# Epoch 8/10
# 1875/1875 [==============================] - 103s 55ms/step - loss: 0.1203 - accuracy: 0.9540 - val_loss: 0.2273 - val_accuracy: 0.9232
# Epoch 9/10
# 1875/1875 [==============================] - 103s 55ms/step - loss: 0.1052 - accuracy: 0.9605 - val_loss: 0.2601 - val_accuracy: 0.9216
# Epoch 10/10
# 1875/1875 [==============================] - 103s 55ms/step - loss: 0.0929 - accuracy: 0.9642 - val_loss: 0.2796 - val_accuracy: 0.9166
# CPU times: user 27min 40s, sys: 24.9 s, total: 28min 5s
# Wall time: 18min 23s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1152)              0
#
#  dense_6 (Dense)             (None, 128)               147584
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_4)
